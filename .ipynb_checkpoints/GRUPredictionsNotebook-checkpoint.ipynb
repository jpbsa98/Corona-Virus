# %% [markdown]
# # **LSTM Prediction model**
# This notebook will be dividided by sections as follows:\
# -Data load\
# -Data Preparation\
# -Build LSTM\
# -Fit LSTM\
# -Forecast Predictions\

# %% [markdown]
# ### **Data Loading**

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.callbacks import ModelCheckpoint
from datetime import datetime as dt
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
import random


confirmed_cases = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv')
confirmed_deaths = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv')
confirmed_recovered = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_recovered_global.csv')

# %%
confirmed_cases
# Out:
#     Province/State         Country/Region        Lat       Long  1/22/20  \
# 0              NaN            Afghanistan  33.000000  65.000000        0
# 1              NaN                Albania  41.153300  20.168300        0
# 2              NaN                Algeria  28.033900   1.659600        0
# 3              NaN                Andorra  42.506300   1.521800        0
# 4              NaN                 Angola -11.202700  17.873900        0
# ..             ...                    ...        ...        ...      ...
# 261            NaN  Sao Tome and Principe   0.186360   6.613081        0
# 262            NaN                  Yemen  15.552727  48.516388        0
# 263            NaN                Comoros -11.645500  43.333300        0
# 264            NaN             Tajikistan  38.861034  71.276093        0
# 265            NaN                Lesotho -29.609988  28.233608        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  6/14/20  6/15/20  \
# 0          0        0        0        0        0  ...    24766    25527
# 1          0        0        0        0        0  ...     1521     1590
# 2          0        0        0        0        0  ...    10919    11031
# 3          0        0        0        0        0  ...      853      853
# 4          0        0        0        0        0  ...      140      142
# ..       ...      ...      ...      ...      ...  ...      ...      ...
# 261        0        0        0        0        0  ...      661      662
# 262        0        0        0        0        0  ...      728      844
# 263        0        0        0        0        0  ...      176      176
# 264        0        0        0        0        0  ...     5035     5097
# 265        0        0        0        0        0  ...        4        4
#
#      6/16/20  6/17/20  6/18/20  6/19/20  6/20/20  6/21/20  6/22/20  6/23/20
# 0      26310    26874    27532    27878    28424    28833    29157    29481
# 1       1672     1722     1788     1838     1891     1962     1995     2047
# 2      11147    11268    11385    11504    11631    11771    11920    12076
# 3        854      854      855      855      855      855      855      855
# 4        148      155      166      172      176      183      186      189
# ..       ...      ...      ...      ...      ...      ...      ...      ...
# 261      671      683      688      693      698      698      702      707
# 262      885      902      909      919      922      941      967      992
# 263      197      197      210      210      247      247      247      265
# 264     5160     5221     5279     5338     5399     5457     5513     5567
# 265        4        4        4        4        4        4       12       17
#
# [266 rows x 158 columns]

# %% [markdown]
# ### **Data Preparation**
# To prepare the data to feed the LSTM network, eah row is correspondant to a day and each collumn is a total for a specific country as follows:\
# -Total_Cases\
# -Total_Deaths\
# -Total_Recoveries\
# -Days_Gone

# %%
class Data():
    def __init__(self,country):
        self.country = country
        self.confirmed = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv')
        self.deaths = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv')
        self.recovered = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_recovered_global.csv')
        if(country == "World Wide"):
            self.PreparaDataGlobal()
        else:
            self.PreparaData()
        fator=18 # Número de dias que se corrige
        self.CorrigirCasosNegativos(fator,self.new_dataset) 
        pd.DataFrame.to_csv(self.new_dataset,'Dados/new_dataset.csv',index=False)

    def PreparaData(self):
        confirmedPortugal = self.confirmed[ self.confirmed['Country/Region'] != self.country].index
        self.confirmed.drop(confirmedPortugal , inplace=True)
        deathsPortugal = self.deaths[ self.deaths['Country/Region'] != self.country].index
        self.deaths.drop(deathsPortugal , inplace=True)
        recoveredPortugal = self.recovered[ self.recovered['Country/Region'] != self.country].index
        self.recovered.drop(recoveredPortugal , inplace=True)
        self.confirmed = self.confirmed.drop(columns=['Province/State','Country/Region','Lat','Long'])
        self.deaths = self.deaths.drop(columns=['Province/State','Country/Region','Lat','Long'])
        self.recovered = self.recovered.drop(columns=['Province/State','Country/Region','Lat','Long'])
        timesteps = []
        total_infetados = []
        total_Days = []
        total_Deaths = []
        total_Recovered = []
        daily_deaths=[]
        daily_cases=[]
        day_of_week=[]
        self.new_dataset = pd.DataFrame()
        Ground_Zero = dt.strptime('12/31/19','%m/%d/%y')
        for cols in self.confirmed.columns:
            timesteps.append(cols)
            total_infetados.append(self.confirmed[cols].sum())
            current_date = dt.strptime(cols,'%m/%d/%y')
            day_of_week.append(current_date.weekday())
            days_Gone = current_date - Ground_Zero
            total_Days.append(int(days_Gone.days))
            daily_cases.append(self.confirmed[cols].sum()-sum(daily_cases))
        for cols in self.deaths.columns:
            total_Deaths.append(self.deaths[cols].sum())
            daily_deaths.append(self.deaths[cols].sum()-sum(daily_deaths))
        for cols in self.recovered.columns:
            total_Recovered.append(self.recovered[cols].sum())
        self.new_dataset['Total_Cases'] = total_infetados
        self.new_dataset['WeekDay'] = day_of_week
        self.new_dataset['Daily_Cases'] = daily_cases
        self.new_dataset['Daily_Deaths'] = daily_deaths
        self.new_dataset['Total_Recovered'] = total_Recovered
        self.new_dataset['Total_Deaths'] = total_Deaths
        self.new_dataset['Days_Gone'] = total_Days
        
    def PreparaDataGlobal(self):
        self.confirmed = self.confirmed.drop(columns=['Province/State','Country/Region','Lat','Long'])
        self.deaths = self.deaths.drop(columns=['Province/State','Country/Region','Lat','Long'])
        self.recovered = self.recovered.drop(columns=['Province/State','Country/Region','Lat','Long'])
        timesteps = []
        total_infetados = []
        total_Days = []
        total_Deaths = []
        total_Recovered = []
        self.new_dataset = pd.DataFrame()
        Ground_Zero = dt.strptime('12/31/19','%m/%d/%y')
        for cols in self.confirmed.columns:
            timesteps.append(cols)
            total_infetados.append(self.confirmed[cols].sum())
            current_date = dt.strptime(cols,'%m/%d/%y')
            days_Gone = current_date - Ground_Zero
            total_Days.append(int(days_Gone.days))
        for cols in self.deaths.columns:
            total_Deaths.append(self.deaths[cols].sum())
        for cols in self.recovered.columns:
            total_Recovered.append(self.recovered[cols].sum())
        self.new_dataset['Total_Cases'] = total_infetados
        self.new_dataset['Total_Recovered'] = total_Recovered
        self.new_dataset['Total_Deaths'] = total_Deaths
        self.new_dataset['Days_Gone'] = total_Days
    
    def CorrigirCasosNegativos(self,fator,df):
        for index,row in df.iterrows():
            if(row['Daily_Cases']<0):
                df.loc[index-fator:index,'Daily_Cases']=df.loc[index-fator:index,'Daily_Cases'].sub(int(abs(row['Daily_Cases'])/fator))
                df.loc[index-fator:index,'Total_Cases']=df.loc[index-fator:index,'Total_Cases'].sub(int(abs(row['Daily_Cases'])/fator))
                row['Daily_Cases']=int(abs(row['Daily_Cases'])/fator)
        self.new_dataset = df

# %% [markdown]
# ### **Feeding LSTM**
# To feed the LSTM, we give 15 timesteps wich correspond to 15 individual days.\
# The model uses a single column,Total_Cases, to predict the total cases for each country.\
# The Model receives all data normalized in range [-1,1], this maximizes perfomance

# %%
class LSTM():
    def __init__(self):
        self.df = pd.read_csv('Dados/new_dataset.csv')
        self.NormalizeData()
        self.timesteps = 15
        self.nr_parametos=2
        self.PrepareData(self.timesteps)
        self.Build(self.timesteps,self.nr_parametos)
        self.Fit()
    def NormalizeData(self):
        self.scaler = MinMaxScaler(feature_range=(-1, 1))
        self.normalized = self.scaler.fit_transform(self.df)
        #print(self.normalized)
        
    def Denormalize(self,dfNormalized):
        pass
    
    
    def PrepareData(self,timesteps):
        i = 0
        self.X = []
        self.Y = []
        while i in range(len(self.normalized - timesteps)):
            input_index = i + timesteps
            label_index = input_index + 1
            if(label_index < len(self.normalized)):
                self.X.append(self.normalized[i:input_index,1:3])
                self.Y.append(self.normalized[input_index:label_index,2])
            i+=1
        self.X = np.array(self.X)
        self.Y = np.array(self.Y)
        self.X_test = self.X[-10:]
        self.Y_test = self.Y[-10:]
        self.X = self.X[:-10]
        self.Y = self.Y[:-10]
        #print(self.X)
        X = self.X
        #print(self.Y)
        Y=self.Y
    
    '''
    def Prepare_Data(self,dataset):
        x = dataset.drop(columns=['Total_Deaths'])
        self.X = x.to_numpy()
        y = dataset['Total_Deaths']
        self.Y = y.to_numpy()
        self.Y = self.Y.astype(float)
    '''
    def Build(self,janela,nmr_parametros):
        self.model = keras.Sequential()
        self.model.add(keras.layers.LSTM(32, input_shape=(janela, nmr_parametros), return_sequences=True))
        self.model.add(keras.layers.LSTM(64, return_sequences=True))
        self.model.add(keras.layers.LSTM(128, return_sequences=False))
        self.model.add(keras.layers.Dropout(0.2))
        self.model.add(keras.layers.Dense(32, activation="relu", kernel_initializer="uniform"))
        self.model.add(keras.layers.Dropout(0.2))
        self.model.add(keras.layers.Dense(1, activation="linear"))

    def RMSE(self,y_true,y_pred):
        return keras.backend.sqrt(keras.backend.mean(keras.backend.square(y_pred - y_true)))

    def Fit(self):
        self.model.compile(loss=self.RMSE,optimizer=keras.optimizers.Adam(),metrics=['mae',self.RMSE])
        try:
            self.model.load_weights("model.h5")
        except:
            print('Model not found')
        self.history = self.model.fit(x=self.X,y=self.Y,epochs=150,batch_size = 7,validation_split=0.05,shuffle=False,verbose=False)
        self.model.save_weights("model.h5")
    def PredictTest(self,data):
        result = self.model.predict(data,verbose=False)
        results = []
        for res in result:
            Denormalized = np.ndarray((1,7))
            Denormalized[0][0] = -1
            Denormalized[0][1] = -1
            Denormalized[0][2] = res
            Denormalized[0][3] = -1
            Denormalized[0][4] = -1
            Denormalized[0][5] = -1
            Denormalized[0][6] = -1
            #print(self.scaler)
            #print(self.normalized)
            value = self.scaler.inverse_transform(Denormalized)
            #print(value)
            results.append(value[0][2])
        return results
    
    def Predict(self,data):
        result = self.model.predict(data,verbose=False)
        return result
        
    def forecast(self):
        timesteps= self.timesteps
        multisteps=50
        data_norm=pd.DataFrame(self.normalized)
        input_seq=data_norm[-timesteps:].values
        inp=input_seq[:,1:3]
        
        
        predictions=list()
        
        inp = np.array(inp).astype('float32')
        #print(inp)
        for step in range(1, multisteps+1):
            
            inp=inp.reshape(1,timesteps,2)
            
            taxa_Erro = random.uniform(-0.005,0.005 )

            yhat=self.Predict(inp) + taxa_Erro
            
            Denormalized = np.ndarray((1,7))
            Denormalized[0][0] = -1
            Denormalized[0][1] = inp[0][inp.shape[1]-1][1]
            Denormalized[0][2] = yhat
            Denormalized[0][3] = -1
            Denormalized[0][4] = -1
            Denormalized[0][5] = -1
            Denormalized[0][6] = -1
            #print(self.scaler)
            #print(self.normalized)
            value = self.scaler.inverse_transform(Denormalized)
            #print(value)
            predictions.append(value[0][2])
            #predictions.append(yhat[0][0])
            newCase = np.array((float(yhat),inp[0][inp.shape[1]-7][1]))  #
            inp = np.append(inp, newCase)
            inp = np.reshape(inp,(-1,2))
            inp=inp[-timesteps:,:]
            #print(inp)
        self.PredictionGraph(predictions)
    def PredictionGraph(self,prediction):
        new_pred = []
        verificador = 0
        for pred in prediction:
            if(verificador == 0):  
                new_pred.append(self.df['Total_Cases'].iloc[-1] + int(pred))
                verificador = 1
            else:
                new_pred.append(new_pred[-1] + int(pred))
        fig, ax = plt.subplots(figsize=(20, 10))
        fig.suptitle('Previsao Casos ', fontweight='bold',fontsize=30, color='#0c3c6e')
        plt.xlabel('Dia', fontsize=20)
        plt.ylabel('Previsão', fontsize=20)
        ax.plot(np.arange(len(self.df)),(self.df['Total_Cases']), label='Days Gone with real data')
        ax.plot(np.arange(len(self.df),len(self.df) + len(new_pred)),(new_pred), label='50 days LSTM prediction')
        ax.legend(fancybox=True, framealpha=1, shadow=True, borderpad=1,fontsize='15')
        plt.xticks(fontsize=16)
        plt.yticks(fontsize=16)
              
        ax.grid()
        #fig.savefig('static/lstm.png')
        
        
        #-------------------------------------------------Second Graph---------------------------------------------------
        
        fig, ax = plt.subplots(figsize=(20, 10))
        fig.suptitle('Daily Corona Cases ', fontsize=15, color='#0c3c6e')

        plt.xlabel('Day', fontsize=10)
        plt.ylabel('Cases per day', fontsize=10)
        
        DenormalizedData = pd.read_csv('Dados/new_dataset.csv')
        
        DenormalizedData=DenormalizedData[DenormalizedData['Total_Cases']>0]
        
        df_values = pd.DataFrame()
        df_values['CasosDiarios']=DenormalizedData['Daily_Cases']
        
        df_values = df_values.reset_index()
        df_values = df_values.drop(['index'],axis=1)

        ax.bar(df_values.index,df_values[:]['CasosDiarios'],label='Real')
        last_index = df_values.index[-1] + 1
        index = []
        for i in range(len(prediction)):
            index.append(i+last_index)
        ax.bar(index,prediction,label='Previsão')
        ax.grid()
        #fig.savefig('static/Casos_diarios.png')
        ax.legend(fancybox=True, framealpha=1, shadow=True, borderpad=1,fontsize='15')
        plt.show()

    def barplot(self,predictions):
        teste = []
        for res in self.Y_test.flatten():
            Denormalized = np.ndarray((1,7))
            Denormalized[0][0] = -1
            Denormalized[0][1] = -1
            Denormalized[0][2] = res
            Denormalized[0][3] = -1
            Denormalized[0][4] = -1
            Denormalized[0][5] = -1
            Denormalized[0][6] = -1
            #print(self.scaler)
            #print(self.normalized)
            value = self.scaler.inverse_transform(Denormalized)
            #print(value)
            teste.append(value[0][2])
        
        df = pd.DataFrame({'Actual': teste, 'Predicted': np.asarray(predictions).flatten()})

        df1 = df.head(25)
        df1.plot(kind='bar',figsize=(16,10))
        plt.grid(which='major', linestyle='-', linewidth='0.5', color='green')
        plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
        plt.show()
        
    def PlotLoss(self):
        fig, ax = plt.subplots(figsize=(20, 10))
        print(self.model.history.history.keys())
        plt.plot(self.model.history.history['loss'])
        plt.plot(self.model.history.history['val_loss'])
        plt.title('loss vs val_loss')
        plt.ylabel('loss')
        plt.xlabel('epoch')
        plt.legend(['loss'], loc='upper left')
        plt.show()

# %%
class LSTMDeaths():
    def __init__(self):
        self.df = pd.read_csv('Dados/new_dataset.csv')
        self.NormalizeData()
        self.timesteps = 15
        self.nr_parametos=3
        self.PrepareData(self.timesteps)
        self.Build(self.timesteps,self.nr_parametos)
        self.Fit()
    def NormalizeData(self):
        self.scaler = MinMaxScaler(feature_range=(-1, 1))
        self.normalized = self.scaler.fit_transform(self.df)
        #print(self.normalized)
        
    def PrepareData(self,timesteps):
        i = 0
        self.X = []
        self.Y = []
        while i in range(len(self.normalized - timesteps)):
            input_index = i + timesteps
            label_index = input_index + 1
            if(label_index < len(self.normalized)):
                self.X.append(self.normalized[i:input_index,1:4])
                self.Y.append(self.normalized[input_index:label_index,3])
            i+=1
        self.X = np.array(self.X)
        self.Y = np.array(self.Y)
        self.X_test = self.X[-10:]
        self.Y_test = self.Y[-10:]
        self.X = self.X[:-10]
        self.Y = self.Y[:-10]
        #print(self.X)
        X = self.X
        #print(self.Y)
        Y=self.Y
    
    '''
    def Prepare_Data(self,dataset):
        x = dataset.drop(columns=['Total_Deaths'])
        self.X = x.to_numpy()
        y = dataset['Total_Deaths']
        self.Y = y.to_numpy()
        self.Y = self.Y.astype(float)
    '''
    def Build(self,janela,nmr_parametros):
        self.model = keras.Sequential()
        self.model.add(keras.layers.LSTM(32, input_shape=(janela, nmr_parametros), return_sequences=True))
        self.model.add(keras.layers.LSTM(64, return_sequences=True))
        self.model.add(keras.layers.LSTM(128, return_sequences=False))
        self.model.add(keras.layers.Dropout(0.2))
        self.model.add(keras.layers.Dense(32, activation="relu", kernel_initializer="uniform"))
        self.model.add(keras.layers.Dropout(0.2))
        self.model.add(keras.layers.Dense(1, activation="linear"))
    
        
    def RMSE(self,y_true,y_pred):
        return keras.backend.sqrt(keras.backend.mean(keras.backend.square(y_pred - y_true)))

    def Fit(self):
        self.model.compile(loss=self.RMSE,optimizer=keras.optimizers.Adam(),metrics=['mae',self.RMSE])
        try:
            self.model.load_weights("modelDeaths.h5")
        except:
            print('Model not found')
        self.history = self.model.fit(x=self.X,y=self.Y,epochs=150,batch_size = 4,validation_split=0.05,shuffle=False)
        self.model.save_weights("modelDeaths.h5")
    def PredictTest(self,data):
        result = self.model.predict(data,verbose=True)
        print(result)
        results = []
        for res in result:
            Denormalized = np.ndarray((1,7))
            Denormalized[0][0] = -1
            Denormalized[0][1] = -1
            Denormalized[0][2] = -1
            Denormalized[0][3] = res
            Denormalized[0][4] = -1
            Denormalized[0][5] = -1
            Denormalized[0][6] = -1
            #print(self.scaler)
            #print(self.normalized)
            value = self.scaler.inverse_transform(Denormalized)
            #print(value)
            results.append(value[0][3])
        return results
    
    def Predict(self,data):
        result = self.model.predict(data,verbose=True)
        return result
        
    def forecast(self):
        timesteps= self.timesteps
        multisteps=50
        data_norm=pd.DataFrame(self.normalized)
        input_seq=data_norm[-timesteps:].values
        inp=input_seq[:,1:3]
        
        
        predictions=list()
        
        inp = np.array(inp).astype('float32')
        #print(inp)
        for step in range(1, multisteps+1):
            
            inp=inp.reshape(1,timesteps,2)
            
            taxa_Erro = random.uniform(-0.005,0.005 )

            yhat=self.Predict(inp) + taxa_Erro
            
            Denormalized = np.ndarray((1,7))
            Denormalized[0][0] = -1
            Denormalized[0][1] = -1
            Denormalized[0][2] = inp[0][inp.shape[1]-1][1]
            Denormalized[0][3] = yhat
            Denormalized[0][4] = -1
            Denormalized[0][5] = -1
            Denormalized[0][6] = -1
            #print(self.scaler)
            #print(self.normalized)
            value = self.scaler.inverse_transform(Denormalized)
            #print(value)
            predictions.append(value[0][2])
            #predictions.append(yhat[0][0])
            newCase = np.array((float(yhat),inp[0][inp.shape[1]-7][1]))  #
            inp = np.append(inp, newCase)
            inp = np.reshape(inp,(-1,2))
            inp=inp[-timesteps:,:]
            #print(inp)
        self.PredictionGraph(predictions)
    def PredictionGraph(self,prediction):
        new_pred = []
        verificador = 0
        for pred in prediction:
            if(verificador == 0):  
                new_pred.append(self.df['Total_Cases'].iloc[-1] + int(pred))
                verificador = 1
            else:
                new_pred.append(new_pred[-1] + int(pred))
        fig, ax = plt.subplots(figsize=(20, 10))
        fig.suptitle('Previsao Casos ', fontweight='bold',fontsize=30, color='#0c3c6e')
        plt.xlabel('Dia', fontsize=20)
        plt.ylabel('Previsão', fontsize=20)
        ax.plot(np.arange(len(self.df)),(self.df['Total_Cases']), label='Days Gone with real data')
        ax.plot(np.arange(len(self.df),len(self.df) + len(new_pred)),(new_pred), label='50 days LSTM prediction')
        ax.legend(fancybox=True, framealpha=1, shadow=True, borderpad=1,fontsize='15')
        plt.xticks(fontsize=16)
        plt.yticks(fontsize=16)
              
        ax.grid()
        #fig.savefig('static/lstm.png')

    def barplot(self,predictions):
        teste = []
        for res in self.Y_test.flatten():
            Denormalized = np.ndarray((1,7))
            Denormalized[0][0] = -1
            Denormalized[0][1] = -1
            Denormalized[0][2] = -1
            Denormalized[0][3] = res
            Denormalized[0][4] = -1
            Denormalized[0][5] = -1
            Denormalized[0][6] = -1
            #print(self.scaler)
            #print(self.normalized)
            value = self.scaler.inverse_transform(Denormalized)
            #print(value)
            teste.append(value[0][3])
        
        df = pd.DataFrame({'Actual': teste, 'Predicted': np.asarray(predictions).flatten()})

        df1 = df.head(25)
        df1.plot(kind='bar',figsize=(16,10))
        plt.grid(which='major', linestyle='-', linewidth='0.5', color='green')
        plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
        plt.show()
        
    def PlotLoss(self):
        fig, ax = plt.subplots(figsize=(20, 10))
        print(self.model.history.history.keys())
        plt.plot(self.model.history.history['loss'])
        plt.plot(self.model.history.history['val_loss'])
        plt.title('loss vs val_loss')
        plt.ylabel('loss')
        plt.xlabel('epoch')
        plt.legend(['loss'], loc='upper left')
        plt.show()

# %%
country = "Brazil"
data = Data(country)

# %%
data.new_dataset
# Out:
#      Total_Cases  WeekDay  Daily_Cases  Daily_Deaths  Total_Recovered  \
# 0              0        2            0             0                0
# 1              0        3            0             0                0
# 2              0        4            0             0                0
# 3              0        5            0             0                0
# 4              0        6            0             0                0
# ..           ...      ...          ...           ...              ...
# 149      1032913        4        54771          1206           551631
# 150      1067579        5        34666          1022           576779
# 151      1083341        6        15762           615           588118
# 152      1106470        0        23129           680           601736
# 153      1145906        1        39436          1374           627963
#
#      Total_Deaths  Days_Gone
# 0               0         22
# 1               0         23
# 2               0         24
# 3               0         25
# 4               0         26
# ..            ...        ...
# 149         48954        171
# 150         49976        172
# 151         50591        173
# 152         51271        174
# 153         52645        175
#
# [154 rows x 7 columns]

# %%
lstm = LSTM()
lstm.PlotLoss()
# Out:
# dict_keys(['loss', 'mae', 'RMSE', 'val_loss', 'val_mae', 'val_RMSE'])

# %% [markdown]
# ### **Predictions**
# To forecast the future, we feed the last 15 days to predict the next day, then the day predicted gets added to the dataset and the next day is predicted using the last 15 correspondant days.\
# After 15 predictions, the network is using its own predictions, this may cause the error to increase but this way we can calculate when the numbers will stagnate in each country.\
# The graph shown bellow show the predicted numbers for the US, to predict other countries just change the "country" variable in the cell above.

# %%
preds = lstm.PredictTest(lstm.X_test)
lstm.barplot(preds)
#lstm.forecast()

# %%
results = lstm.model.evaluate(lstm.X_test,lstm.Y_test)
# Out:
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3574 - mae: 0.2495 - RMSE: 0.3574

# %%
lstm.forecast()

# %%
lstmDeaths = LSTMDeaths()
# Out:
# Epoch 1/150
# 31/31 [==============================] - 6s 192ms/step - loss: 0.2763 - mae: 0.2493 - RMSE: 0.2752 - val_loss: 0.3885 - val_mae: 0.3366 - val_RMSE: 0.3646
# Epoch 2/150
# 31/31 [==============================] - 3s 110ms/step - loss: 0.2290 - mae: 0.2005 - RMSE: 0.2259 - val_loss: 0.3491 - val_mae: 0.3200 - val_RMSE: 0.3336
# Epoch 3/150
# 31/31 [==============================] - 3s 81ms/step - loss: 0.2124 - mae: 0.1900 - RMSE: 0.2082 - val_loss: 0.3418 - val_mae: 0.3095 - val_RMSE: 0.3313
# Epoch 4/150
# 31/31 [==============================] - 3s 104ms/step - loss: 0.1968 - mae: 0.1760 - RMSE: 0.1948 - val_loss: 0.3311 - val_mae: 0.2982 - val_RMSE: 0.3208
# Epoch 5/150
# 31/31 [==============================] - 3s 96ms/step - loss: 0.1965 - mae: 0.1712 - RMSE: 0.1929 - val_loss: 0.3244 - val_mae: 0.2923 - val_RMSE: 0.3064
# Epoch 6/150
# 31/31 [==============================] - 3s 103ms/step - loss: 0.1830 - mae: 0.1552 - RMSE: 0.1838 - val_loss: 0.3134 - val_mae: 0.2780 - val_RMSE: 0.2952
# Epoch 7/150
# 31/31 [==============================] - 3s 96ms/step - loss: 0.1738 - mae: 0.1451 - RMSE: 0.1710 - val_loss: 0.2895 - val_mae: 0.2573 - val_RMSE: 0.2799
# Epoch 8/150
# 31/31 [==============================] - 3s 86ms/step - loss: 0.2214 - mae: 0.2018 - RMSE: 0.2181 - val_loss: 0.2591 - val_mae: 0.2247 - val_RMSE: 0.2492
# Epoch 9/150
# 31/31 [==============================] - 3s 90ms/step - loss: 0.1575 - mae: 0.1348 - RMSE: 0.1546 - val_loss: 0.2477 - val_mae: 0.2116 - val_RMSE: 0.2330
# Epoch 10/150
# 31/31 [==============================] - 3s 104ms/step - loss: 0.1292 - mae: 0.1097 - RMSE: 0.1303 - val_loss: 0.2551 - val_mae: 0.2274 - val_RMSE: 0.2468
# Epoch 11/150
# 31/31 [==============================] - 3s 94ms/step - loss: 0.1575 - mae: 0.1362 - RMSE: 0.1561 - val_loss: 0.1843 - val_mae: 0.1492 - val_RMSE: 0.1792
# Epoch 12/150
# 31/31 [==============================] - 3s 97ms/step - loss: 0.1483 - mae: 0.1309 - RMSE: 0.1502 - val_loss: 0.2260 - val_mae: 0.1804 - val_RMSE: 0.2253
# Epoch 13/150
# 31/31 [==============================] - 3s 86ms/step - loss: 0.1874 - mae: 0.1624 - RMSE: 0.1837 - val_loss: 0.1459 - val_mae: 0.1241 - val_RMSE: 0.1337
# Epoch 14/150
# 31/31 [==============================] - 3s 97ms/step - loss: 0.1928 - mae: 0.1731 - RMSE: 0.1930 - val_loss: 0.2309 - val_mae: 0.1996 - val_RMSE: 0.2286
# Epoch 15/150
# 31/31 [==============================] - 3s 92ms/step - loss: 0.1508 - mae: 0.1309 - RMSE: 0.1514 - val_loss: 0.1739 - val_mae: 0.1410 - val_RMSE: 0.1674
# Epoch 16/150
# 31/31 [==============================] - 3s 94ms/step - loss: 0.1872 - mae: 0.1697 - RMSE: 0.1846 - val_loss: 0.1983 - val_mae: 0.1641 - val_RMSE: 0.2044
# Epoch 17/150
# 31/31 [==============================] - 3s 82ms/step - loss: 0.1393 - mae: 0.1206 - RMSE: 0.1381 - val_loss: 0.1600 - val_mae: 0.1404 - val_RMSE: 0.1656
# Epoch 18/150
# 31/31 [==============================] - 3s 89ms/step - loss: 0.1468 - mae: 0.1272 - RMSE: 0.1481 - val_loss: 0.1836 - val_mae: 0.1425 - val_RMSE: 0.1854
# Epoch 19/150
# 31/31 [==============================] - 3s 84ms/step - loss: 0.1447 - mae: 0.1189 - RMSE: 0.1426 - val_loss: 0.1277 - val_mae: 0.1191 - val_RMSE: 0.1314
# Epoch 20/150
# 31/31 [==============================] - 3s 112ms/step - loss: 0.1410 - mae: 0.1233 - RMSE: 0.1387 - val_loss: 0.1604 - val_mae: 0.1470 - val_RMSE: 0.1742
# Epoch 21/150
# 31/31 [==============================] - 3s 89ms/step - loss: 0.1139 - mae: 0.1002 - RMSE: 0.1150 - val_loss: 0.1540 - val_mae: 0.1364 - val_RMSE: 0.1671
# Epoch 22/150
# 31/31 [==============================] - 3s 100ms/step - loss: 0.1492 - mae: 0.1284 - RMSE: 0.1506 - val_loss: 0.1146 - val_mae: 0.1054 - val_RMSE: 0.1195
# Epoch 23/150
# 31/31 [==============================] - 3s 91ms/step - loss: 0.1823 - mae: 0.1629 - RMSE: 0.1807 - val_loss: 0.1779 - val_mae: 0.1480 - val_RMSE: 0.1916
# Epoch 24/150
# 31/31 [==============================] - 3s 98ms/step - loss: 0.1496 - mae: 0.1292 - RMSE: 0.1514 - val_loss: 0.1056 - val_mae: 0.0853 - val_RMSE: 0.1009
# Epoch 25/150
# 31/31 [==============================] - 3s 107ms/step - loss: 0.1430 - mae: 0.1257 - RMSE: 0.1441 - val_loss: 0.1429 - val_mae: 0.1223 - val_RMSE: 0.1481
# Epoch 26/150
# 31/31 [==============================] - 3s 95ms/step - loss: 0.1550 - mae: 0.1319 - RMSE: 0.1520 - val_loss: 0.1486 - val_mae: 0.1355 - val_RMSE: 0.1517
# Epoch 27/150
# 31/31 [==============================] - 3s 85ms/step - loss: 0.1664 - mae: 0.1475 - RMSE: 0.1688 - val_loss: 0.1817 - val_mae: 0.1487 - val_RMSE: 0.1984
# Epoch 28/150
# 31/31 [==============================] - 3s 98ms/step - loss: 0.1511 - mae: 0.1305 - RMSE: 0.1500 - val_loss: 0.1270 - val_mae: 0.1127 - val_RMSE: 0.1250
# Epoch 29/150
# 31/31 [==============================] - 3s 104ms/step - loss: 0.1167 - mae: 0.0975 - RMSE: 0.1172 - val_loss: 0.1829 - val_mae: 0.1671 - val_RMSE: 0.1984
# Epoch 30/150
# 31/31 [==============================] - 3s 95ms/step - loss: 0.1409 - mae: 0.1199 - RMSE: 0.1379 - val_loss: 0.1285 - val_mae: 0.1242 - val_RMSE: 0.1335
# Epoch 31/150
# 31/31 [==============================] - 3s 96ms/step - loss: 0.1456 - mae: 0.1281 - RMSE: 0.1432 - val_loss: 0.1183 - val_mae: 0.1122 - val_RMSE: 0.1296
# Epoch 32/150
# 31/31 [==============================] - 3s 93ms/step - loss: 0.1343 - mae: 0.1133 - RMSE: 0.1354 - val_loss: 0.1951 - val_mae: 0.1634 - val_RMSE: 0.2030
# Epoch 33/150
# 31/31 [==============================] - 3s 91ms/step - loss: 0.1653 - mae: 0.1487 - RMSE: 0.1637 - val_loss: 0.1674 - val_mae: 0.1556 - val_RMSE: 0.1729
# Epoch 34/150
# 31/31 [==============================] - 3s 96ms/step - loss: 0.1389 - mae: 0.1207 - RMSE: 0.1397 - val_loss: 0.0874 - val_mae: 0.0840 - val_RMSE: 0.0856
# Epoch 35/150
# 31/31 [==============================] - 3s 87ms/step - loss: 0.1146 - mae: 0.0945 - RMSE: 0.1162 - val_loss: 0.1787 - val_mae: 0.1513 - val_RMSE: 0.1895
# Epoch 36/150
# 31/31 [==============================] - 3s 94ms/step - loss: 0.1172 - mae: 0.1020 - RMSE: 0.1193 - val_loss: 0.2115 - val_mae: 0.1742 - val_RMSE: 0.2253
# Epoch 37/150
# 31/31 [==============================] - 3s 97ms/step - loss: 0.1750 - mae: 0.1549 - RMSE: 0.1767 - val_loss: 0.1148 - val_mae: 0.1039 - val_RMSE: 0.1089
# Epoch 38/150
# 31/31 [==============================] - 3s 94ms/step - loss: 0.1385 - mae: 0.1199 - RMSE: 0.1412 - val_loss: 0.1552 - val_mae: 0.1444 - val_RMSE: 0.1664
# Epoch 39/150
# 31/31 [==============================] - 3s 106ms/step - loss: 0.1333 - mae: 0.1137 - RMSE: 0.1322 - val_loss: 0.0874 - val_mae: 0.0740 - val_RMSE: 0.0917
# Epoch 40/150
# 31/31 [==============================] - 3s 93ms/step - loss: 0.1307 - mae: 0.1108 - RMSE: 0.1277 - val_loss: 0.1385 - val_mae: 0.1328 - val_RMSE: 0.1534
# Epoch 41/150
# 31/31 [==============================] - 3s 105ms/step - loss: 0.1574 - mae: 0.1377 - RMSE: 0.1580 - val_loss: 0.1247 - val_mae: 0.1024 - val_RMSE: 0.1282
# Epoch 42/150
# 31/31 [==============================] - 3s 100ms/step - loss: 0.1618 - mae: 0.1438 - RMSE: 0.1584 - val_loss: 0.1614 - val_mae: 0.1406 - val_RMSE: 0.1752
# Epoch 43/150
# 31/31 [==============================] - 3s 91ms/step - loss: 0.1275 - mae: 0.1073 - RMSE: 0.1250 - val_loss: 0.1456 - val_mae: 0.1314 - val_RMSE: 0.1491
# Epoch 44/150
# 31/31 [==============================] - 3s 89ms/step - loss: 0.1324 - mae: 0.1122 - RMSE: 0.1318 - val_loss: 0.1238 - val_mae: 0.1149 - val_RMSE: 0.1394
# Epoch 45/150
# 31/31 [==============================] - 3s 94ms/step - loss: 0.1215 - mae: 0.1038 - RMSE: 0.1235 - val_loss: 0.1564 - val_mae: 0.1333 - val_RMSE: 0.1708
# Epoch 46/150
# 31/31 [==============================] - 3s 106ms/step - loss: 0.1401 - mae: 0.1214 - RMSE: 0.1393 - val_loss: 0.1559 - val_mae: 0.1360 - val_RMSE: 0.1676
# Epoch 47/150
# 31/31 [==============================] - 3s 98ms/step - loss: 0.1112 - mae: 0.0958 - RMSE: 0.1105 - val_loss: 0.1467 - val_mae: 0.1261 - val_RMSE: 0.1570
# Epoch 48/150
# 31/31 [==============================] - 4s 119ms/step - loss: 0.1328 - mae: 0.1151 - RMSE: 0.1358 - val_loss: 0.1826 - val_mae: 0.1649 - val_RMSE: 0.1978
# Epoch 49/150
# 31/31 [==============================] - 3s 100ms/step - loss: 0.1328 - mae: 0.1139 - RMSE: 0.1301 - val_loss: 0.1332 - val_mae: 0.1184 - val_RMSE: 0.1411
# Epoch 50/150
# 31/31 [==============================] - 3s 99ms/step - loss: 0.1490 - mae: 0.1330 - RMSE: 0.1540 - val_loss: 0.1826 - val_mae: 0.1729 - val_RMSE: 0.2010
# Epoch 51/150
# 31/31 [==============================] - 3s 96ms/step - loss: 0.1154 - mae: 0.0991 - RMSE: 0.1141 - val_loss: 0.1543 - val_mae: 0.1456 - val_RMSE: 0.1598
# Epoch 52/150
# 31/31 [==============================] - 3s 88ms/step - loss: 0.1440 - mae: 0.1237 - RMSE: 0.1450 - val_loss: 0.1860 - val_mae: 0.1807 - val_RMSE: 0.2124
# Epoch 53/150
# 31/31 [==============================] - 3s 96ms/step - loss: 0.1332 - mae: 0.1108 - RMSE: 0.1352 - val_loss: 0.1695 - val_mae: 0.1465 - val_RMSE: 0.1765
# Epoch 54/150
# 31/31 [==============================] - 3s 107ms/step - loss: 0.1265 - mae: 0.1081 - RMSE: 0.1257 - val_loss: 0.1617 - val_mae: 0.1463 - val_RMSE: 0.1801
# Epoch 55/150
# 31/31 [==============================] - 3s 96ms/step - loss: 0.1043 - mae: 0.0894 - RMSE: 0.1030 - val_loss: 0.1624 - val_mae: 0.1571 - val_RMSE: 0.1751
# Epoch 56/150
# 31/31 [==============================] - 3s 101ms/step - loss: 0.1211 - mae: 0.1064 - RMSE: 0.1207 - val_loss: 0.1619 - val_mae: 0.1305 - val_RMSE: 0.1651
# Epoch 57/150
# 31/31 [==============================] - 3s 100ms/step - loss: 0.1468 - mae: 0.1311 - RMSE: 0.1451 - val_loss: 0.2242 - val_mae: 0.1653 - val_RMSE: 0.2348
# Epoch 58/150
# 31/31 [==============================] - 4s 114ms/step - loss: 0.1149 - mae: 0.0972 - RMSE: 0.1161 - val_loss: 0.2286 - val_mae: 0.1975 - val_RMSE: 0.2403
# Epoch 59/150
# 31/31 [==============================] - 3s 111ms/step - loss: 0.1093 - mae: 0.0936 - RMSE: 0.1074 - val_loss: 0.1434 - val_mae: 0.1200 - val_RMSE: 0.1562
# Epoch 60/150
# 31/31 [==============================] - 3s 95ms/step - loss: 0.1192 - mae: 0.1042 - RMSE: 0.1183 - val_loss: 0.1615 - val_mae: 0.1200 - val_RMSE: 0.1810
# Epoch 61/150
# 31/31 [==============================] - 3s 104ms/step - loss: 0.1276 - mae: 0.1116 - RMSE: 0.1270 - val_loss: 0.1543 - val_mae: 0.1382 - val_RMSE: 0.1675
# Epoch 62/150
# 31/31 [==============================] - 3s 94ms/step - loss: 0.1407 - mae: 0.1259 - RMSE: 0.1382 - val_loss: 0.1303 - val_mae: 0.1159 - val_RMSE: 0.1374
# Epoch 63/150
# 31/31 [==============================] - 3s 89ms/step - loss: 0.1324 - mae: 0.1151 - RMSE: 0.1361 - val_loss: 0.1806 - val_mae: 0.1633 - val_RMSE: 0.1992
# Epoch 64/150
# 31/31 [==============================] - 3s 108ms/step - loss: 0.1154 - mae: 0.0998 - RMSE: 0.1159 - val_loss: 0.1015 - val_mae: 0.0843 - val_RMSE: 0.1023
# Epoch 65/150
# 31/31 [==============================] - 3s 99ms/step - loss: 0.1254 - mae: 0.1058 - RMSE: 0.1262 - val_loss: 0.1410 - val_mae: 0.1179 - val_RMSE: 0.1569
# Epoch 66/150
# 31/31 [==============================] - 3s 100ms/step - loss: 0.1215 - mae: 0.0989 - RMSE: 0.1210 - val_loss: 0.1200 - val_mae: 0.0943 - val_RMSE: 0.1200
# Epoch 67/150
# 31/31 [==============================] - 3s 94ms/step - loss: 0.1121 - mae: 0.0954 - RMSE: 0.1115 - val_loss: 0.1415 - val_mae: 0.1214 - val_RMSE: 0.1514
# Epoch 68/150
# 31/31 [==============================] - 3s 86ms/step - loss: 0.1313 - mae: 0.1124 - RMSE: 0.1319 - val_loss: 0.1328 - val_mae: 0.1036 - val_RMSE: 0.1402
# Epoch 69/150
# 31/31 [==============================] - 3s 97ms/step - loss: 0.1416 - mae: 0.1250 - RMSE: 0.1477 - val_loss: 0.1898 - val_mae: 0.1660 - val_RMSE: 0.2077
# Epoch 70/150
# 31/31 [==============================] - 3s 82ms/step - loss: 0.1021 - mae: 0.0851 - RMSE: 0.1018 - val_loss: 0.1408 - val_mae: 0.1229 - val_RMSE: 0.1499
# Epoch 71/150
# 31/31 [==============================] - 3s 86ms/step - loss: 0.1258 - mae: 0.1087 - RMSE: 0.1249 - val_loss: 0.1522 - val_mae: 0.1337 - val_RMSE: 0.1605
# Epoch 72/150
# 31/31 [==============================] - 3s 98ms/step - loss: 0.1191 - mae: 0.1018 - RMSE: 0.1193 - val_loss: 0.1926 - val_mae: 0.1640 - val_RMSE: 0.2059
# Epoch 73/150
# 31/31 [==============================] - 3s 89ms/step - loss: 0.1192 - mae: 0.1031 - RMSE: 0.1185 - val_loss: 0.0991 - val_mae: 0.0833 - val_RMSE: 0.1026
# Epoch 74/150
# 31/31 [==============================] - 3s 94ms/step - loss: 0.1185 - mae: 0.1006 - RMSE: 0.1184 - val_loss: 0.1577 - val_mae: 0.1228 - val_RMSE: 0.1689
# Epoch 75/150
# 31/31 [==============================] - 3s 85ms/step - loss: 0.1330 - mae: 0.1157 - RMSE: 0.1313 - val_loss: 0.2022 - val_mae: 0.1818 - val_RMSE: 0.2188
# Epoch 76/150
# 31/31 [==============================] - 3s 92ms/step - loss: 0.1024 - mae: 0.0880 - RMSE: 0.1022 - val_loss: 0.1516 - val_mae: 0.1408 - val_RMSE: 0.1625
# Epoch 77/150
# 31/31 [==============================] - 3s 100ms/step - loss: 0.1169 - mae: 0.0975 - RMSE: 0.1145 - val_loss: 0.1273 - val_mae: 0.1111 - val_RMSE: 0.1313
# Epoch 78/150
# 31/31 [==============================] - 3s 96ms/step - loss: 0.1119 - mae: 0.0962 - RMSE: 0.1093 - val_loss: 0.1036 - val_mae: 0.0963 - val_RMSE: 0.1144
# Epoch 79/150
# 31/31 [==============================] - 3s 92ms/step - loss: 0.1244 - mae: 0.1115 - RMSE: 0.1242 - val_loss: 0.1674 - val_mae: 0.1617 - val_RMSE: 0.1771
# Epoch 80/150
# 31/31 [==============================] - 3s 87ms/step - loss: 0.1179 - mae: 0.1032 - RMSE: 0.1174 - val_loss: 0.1307 - val_mae: 0.1020 - val_RMSE: 0.1286
# Epoch 81/150
# 31/31 [==============================] - 3s 88ms/step - loss: 0.1466 - mae: 0.1301 - RMSE: 0.1524 - val_loss: 0.2033 - val_mae: 0.1817 - val_RMSE: 0.2166
# Epoch 82/150
# 31/31 [==============================] - 3s 93ms/step - loss: 0.0868 - mae: 0.0738 - RMSE: 0.0859 - val_loss: 0.1378 - val_mae: 0.1215 - val_RMSE: 0.1407
# Epoch 83/150
# 31/31 [==============================] - 3s 82ms/step - loss: 0.1151 - mae: 0.0988 - RMSE: 0.1130 - val_loss: 0.1125 - val_mae: 0.0909 - val_RMSE: 0.1199
# Epoch 84/150
# 31/31 [==============================] - 3s 88ms/step - loss: 0.1127 - mae: 0.0961 - RMSE: 0.1132 - val_loss: 0.1818 - val_mae: 0.1664 - val_RMSE: 0.1936
# Epoch 85/150
# 31/31 [==============================] - 3s 108ms/step - loss: 0.1250 - mae: 0.1067 - RMSE: 0.1220 - val_loss: 0.2257 - val_mae: 0.1792 - val_RMSE: 0.2369
# Epoch 86/150
# 31/31 [==============================] - 3s 109ms/step - loss: 0.1268 - mae: 0.1103 - RMSE: 0.1301 - val_loss: 0.1600 - val_mae: 0.1273 - val_RMSE: 0.1713
# Epoch 87/150
# 31/31 [==============================] - 3s 99ms/step - loss: 0.0948 - mae: 0.0815 - RMSE: 0.0957 - val_loss: 0.1622 - val_mae: 0.1385 - val_RMSE: 0.1756
# Epoch 88/150
# 31/31 [==============================] - 3s 96ms/step - loss: 0.1102 - mae: 0.0938 - RMSE: 0.1108 - val_loss: 0.1525 - val_mae: 0.1252 - val_RMSE: 0.1564
# Epoch 89/150
# 31/31 [==============================] - 3s 99ms/step - loss: 0.1162 - mae: 0.0967 - RMSE: 0.1138 - val_loss: 0.1716 - val_mae: 0.1490 - val_RMSE: 0.1843
# Epoch 90/150
# 31/31 [==============================] - 3s 89ms/step - loss: 0.0985 - mae: 0.0814 - RMSE: 0.0985 - val_loss: 0.1312 - val_mae: 0.1008 - val_RMSE: 0.1375
# Epoch 91/150
# 31/31 [==============================] - 3s 101ms/step - loss: 0.1042 - mae: 0.0866 - RMSE: 0.1071 - val_loss: 0.0793 - val_mae: 0.0637 - val_RMSE: 0.0879
# Epoch 92/150
# 31/31 [==============================] - 3s 90ms/step - loss: 0.1292 - mae: 0.1152 - RMSE: 0.1288 - val_loss: 0.1551 - val_mae: 0.1211 - val_RMSE: 0.1704
# Epoch 93/150
# 31/31 [==============================] - 3s 85ms/step - loss: 0.1219 - mae: 0.1044 - RMSE: 0.1210 - val_loss: 0.1834 - val_mae: 0.1607 - val_RMSE: 0.1908
# Epoch 94/150
# 31/31 [==============================] - 3s 100ms/step - loss: 0.1469 - mae: 0.1265 - RMSE: 0.1442 - val_loss: 0.1923 - val_mae: 0.1428 - val_RMSE: 0.2140
# Epoch 95/150
# 31/31 [==============================] - 3s 87ms/step - loss: 0.0974 - mae: 0.0814 - RMSE: 0.0956 - val_loss: 0.1964 - val_mae: 0.1521 - val_RMSE: 0.2132
# Epoch 96/150
# 31/31 [==============================] - 3s 96ms/step - loss: 0.1274 - mae: 0.1097 - RMSE: 0.1262 - val_loss: 0.1641 - val_mae: 0.1328 - val_RMSE: 0.1665
# Epoch 97/150
# 31/31 [==============================] - 3s 100ms/step - loss: 0.1293 - mae: 0.1158 - RMSE: 0.1294 - val_loss: 0.2143 - val_mae: 0.1846 - val_RMSE: 0.2332
# Epoch 98/150
# 31/31 [==============================] - 3s 104ms/step - loss: 0.1030 - mae: 0.0894 - RMSE: 0.1047 - val_loss: 0.2102 - val_mae: 0.1843 - val_RMSE: 0.2263
# Epoch 99/150
# 31/31 [==============================] - 3s 99ms/step - loss: 0.1232 - mae: 0.1027 - RMSE: 0.1250 - val_loss: 0.1082 - val_mae: 0.0937 - val_RMSE: 0.1122
# Epoch 100/150
# 31/31 [==============================] - 3s 103ms/step - loss: 0.1126 - mae: 0.0934 - RMSE: 0.1156 - val_loss: 0.1678 - val_mae: 0.1467 - val_RMSE: 0.1814
# Epoch 101/150
# 31/31 [==============================] - 3s 99ms/step - loss: 0.0895 - mae: 0.0755 - RMSE: 0.0879 - val_loss: 0.1614 - val_mae: 0.1338 - val_RMSE: 0.1699
# Epoch 102/150
# 31/31 [==============================] - 3s 98ms/step - loss: 0.1159 - mae: 0.0957 - RMSE: 0.1154 - val_loss: 0.1459 - val_mae: 0.1388 - val_RMSE: 0.1602
# Epoch 103/150
# 31/31 [==============================] - 3s 111ms/step - loss: 0.1068 - mae: 0.0854 - RMSE: 0.1045 - val_loss: 0.1290 - val_mae: 0.1138 - val_RMSE: 0.1364
# Epoch 104/150
# 31/31 [==============================] - 3s 107ms/step - loss: 0.1071 - mae: 0.0927 - RMSE: 0.1094 - val_loss: 0.1747 - val_mae: 0.1477 - val_RMSE: 0.1872
# Epoch 105/150
# 31/31 [==============================] - 4s 118ms/step - loss: 0.1330 - mae: 0.1126 - RMSE: 0.1333 - val_loss: 0.1162 - val_mae: 0.0931 - val_RMSE: 0.1114
# Epoch 106/150
# 31/31 [==============================] - 3s 101ms/step - loss: 0.1193 - mae: 0.0983 - RMSE: 0.1193 - val_loss: 0.1360 - val_mae: 0.1279 - val_RMSE: 0.1400
# Epoch 107/150
# 31/31 [==============================] - 3s 106ms/step - loss: 0.1121 - mae: 0.0944 - RMSE: 0.1110 - val_loss: 0.1378 - val_mae: 0.1233 - val_RMSE: 0.1420
# Epoch 108/150
# 31/31 [==============================] - 3s 109ms/step - loss: 0.1096 - mae: 0.0941 - RMSE: 0.1121 - val_loss: 0.1505 - val_mae: 0.1187 - val_RMSE: 0.1617
# Epoch 109/150
# 31/31 [==============================] - 3s 95ms/step - loss: 0.1166 - mae: 0.1007 - RMSE: 0.1151 - val_loss: 0.1729 - val_mae: 0.1632 - val_RMSE: 0.1759
# Epoch 110/150
# 31/31 [==============================] - 3s 95ms/step - loss: 0.1156 - mae: 0.0975 - RMSE: 0.1143 - val_loss: 0.1448 - val_mae: 0.1208 - val_RMSE: 0.1533
# Epoch 111/150
# 31/31 [==============================] - 3s 92ms/step - loss: 0.1127 - mae: 0.0955 - RMSE: 0.1117 - val_loss: 0.2037 - val_mae: 0.1689 - val_RMSE: 0.2182
# Epoch 112/150
# 31/31 [==============================] - 3s 106ms/step - loss: 0.1161 - mae: 0.0959 - RMSE: 0.1183 - val_loss: 0.0702 - val_mae: 0.0648 - val_RMSE: 0.0697
# Epoch 113/150
# 31/31 [==============================] - 3s 88ms/step - loss: 0.1092 - mae: 0.0957 - RMSE: 0.1098 - val_loss: 0.1447 - val_mae: 0.1364 - val_RMSE: 0.1527
# Epoch 114/150
# 31/31 [==============================] - 3s 99ms/step - loss: 0.1131 - mae: 0.0961 - RMSE: 0.1127 - val_loss: 0.0953 - val_mae: 0.0772 - val_RMSE: 0.1039
# Epoch 115/150
# 31/31 [==============================] - 3s 94ms/step - loss: 0.1137 - mae: 0.0951 - RMSE: 0.1134 - val_loss: 0.1450 - val_mae: 0.1213 - val_RMSE: 0.1584
# Epoch 116/150
# 31/31 [==============================] - 3s 94ms/step - loss: 0.1233 - mae: 0.1076 - RMSE: 0.1253 - val_loss: 0.1208 - val_mae: 0.0955 - val_RMSE: 0.1223
# Epoch 117/150
# 31/31 [==============================] - 3s 94ms/step - loss: 0.1111 - mae: 0.0945 - RMSE: 0.1102 - val_loss: 0.1205 - val_mae: 0.1025 - val_RMSE: 0.1327
# Epoch 118/150
# 31/31 [==============================] - 3s 105ms/step - loss: 0.0803 - mae: 0.0657 - RMSE: 0.0786 - val_loss: 0.1404 - val_mae: 0.1221 - val_RMSE: 0.1561
# Epoch 119/150
# 31/31 [==============================] - 3s 92ms/step - loss: 0.0923 - mae: 0.0783 - RMSE: 0.0905 - val_loss: 0.0742 - val_mae: 0.0680 - val_RMSE: 0.0796
# Epoch 120/150
# 31/31 [==============================] - 3s 97ms/step - loss: 0.1274 - mae: 0.1114 - RMSE: 0.1269 - val_loss: 0.0523 - val_mae: 0.0401 - val_RMSE: 0.0503
# Epoch 121/150
# 31/31 [==============================] - 3s 104ms/step - loss: 0.1199 - mae: 0.0997 - RMSE: 0.1194 - val_loss: 0.1145 - val_mae: 0.1051 - val_RMSE: 0.1243
# Epoch 122/150
# 31/31 [==============================] - 3s 92ms/step - loss: 0.1105 - mae: 0.0945 - RMSE: 0.1151 - val_loss: 0.1708 - val_mae: 0.1503 - val_RMSE: 0.1731
# Epoch 123/150
# 31/31 [==============================] - 3s 89ms/step - loss: 0.1262 - mae: 0.1070 - RMSE: 0.1243 - val_loss: 0.2005 - val_mae: 0.1544 - val_RMSE: 0.2204
# Epoch 124/150
# 31/31 [==============================] - 3s 97ms/step - loss: 0.0944 - mae: 0.0803 - RMSE: 0.0955 - val_loss: 0.1936 - val_mae: 0.1691 - val_RMSE: 0.2088
# Epoch 125/150
# 31/31 [==============================] - 3s 99ms/step - loss: 0.1189 - mae: 0.1002 - RMSE: 0.1173 - val_loss: 0.0711 - val_mae: 0.0650 - val_RMSE: 0.0757
# Epoch 126/150
# 31/31 [==============================] - 3s 102ms/step - loss: 0.1492 - mae: 0.1325 - RMSE: 0.1477 - val_loss: 0.1278 - val_mae: 0.1096 - val_RMSE: 0.1411
# Epoch 127/150
# 31/31 [==============================] - 3s 97ms/step - loss: 0.1095 - mae: 0.0922 - RMSE: 0.1069 - val_loss: 0.1291 - val_mae: 0.1057 - val_RMSE: 0.1286
# Epoch 128/150
# 31/31 [==============================] - 3s 93ms/step - loss: 0.1057 - mae: 0.0908 - RMSE: 0.1087 - val_loss: 0.1653 - val_mae: 0.1388 - val_RMSE: 0.1780
# Epoch 129/150
# 31/31 [==============================] - 3s 89ms/step - loss: 0.0901 - mae: 0.0755 - RMSE: 0.0881 - val_loss: 0.1486 - val_mae: 0.1211 - val_RMSE: 0.1606
# Epoch 130/150
# 31/31 [==============================] - 3s 90ms/step - loss: 0.1123 - mae: 0.0963 - RMSE: 0.1102 - val_loss: 0.1509 - val_mae: 0.1381 - val_RMSE: 0.1624
# Epoch 131/150
# 31/31 [==============================] - 3s 98ms/step - loss: 0.1221 - mae: 0.1050 - RMSE: 0.1201 - val_loss: 0.0678 - val_mae: 0.0548 - val_RMSE: 0.0664
# Epoch 132/150
# 31/31 [==============================] - 3s 96ms/step - loss: 0.1075 - mae: 0.0932 - RMSE: 0.1060 - val_loss: 0.1578 - val_mae: 0.1403 - val_RMSE: 0.1712
# Epoch 133/150
# 31/31 [==============================] - 3s 92ms/step - loss: 0.0922 - mae: 0.0794 - RMSE: 0.0963 - val_loss: 0.1738 - val_mae: 0.1558 - val_RMSE: 0.1807
# Epoch 134/150
# 31/31 [==============================] - 3s 99ms/step - loss: 0.0940 - mae: 0.0802 - RMSE: 0.0935 - val_loss: 0.1035 - val_mae: 0.0859 - val_RMSE: 0.1068
# Epoch 135/150
# 31/31 [==============================] - 3s 91ms/step - loss: 0.0884 - mae: 0.0731 - RMSE: 0.0867 - val_loss: 0.1168 - val_mae: 0.1098 - val_RMSE: 0.1258
# Epoch 136/150
# 31/31 [==============================] - 3s 93ms/step - loss: 0.1198 - mae: 0.1014 - RMSE: 0.1181 - val_loss: 0.1538 - val_mae: 0.1437 - val_RMSE: 0.1620
# Epoch 137/150
# 31/31 [==============================] - 3s 102ms/step - loss: 0.1098 - mae: 0.0907 - RMSE: 0.1105 - val_loss: 0.1121 - val_mae: 0.0800 - val_RMSE: 0.1108
# Epoch 138/150
# 31/31 [==============================] - 3s 94ms/step - loss: 0.1109 - mae: 0.0954 - RMSE: 0.1138 - val_loss: 0.1257 - val_mae: 0.1092 - val_RMSE: 0.1318
# Epoch 139/150
# 31/31 [==============================] - 3s 112ms/step - loss: 0.0948 - mae: 0.0791 - RMSE: 0.0937 - val_loss: 0.1139 - val_mae: 0.0906 - val_RMSE: 0.1154
# Epoch 140/150
# 31/31 [==============================] - 3s 109ms/step - loss: 0.1192 - mae: 0.1049 - RMSE: 0.1230 - val_loss: 0.1719 - val_mae: 0.1580 - val_RMSE: 0.1847
# Epoch 141/150
# 31/31 [==============================] - 4s 120ms/step - loss: 0.1216 - mae: 0.1035 - RMSE: 0.1202 - val_loss: 0.1238 - val_mae: 0.1086 - val_RMSE: 0.1284
# Epoch 142/150
# 31/31 [==============================] - 3s 106ms/step - loss: 0.1338 - mae: 0.1142 - RMSE: 0.1347 - val_loss: 0.1465 - val_mae: 0.1281 - val_RMSE: 0.1568
# Epoch 143/150
# 31/31 [==============================] - 4s 118ms/step - loss: 0.1209 - mae: 0.1012 - RMSE: 0.1196 - val_loss: 0.1374 - val_mae: 0.1036 - val_RMSE: 0.1329
# Epoch 144/150
# 31/31 [==============================] - 3s 106ms/step - loss: 0.1090 - mae: 0.0951 - RMSE: 0.1069 - val_loss: 0.1442 - val_mae: 0.1383 - val_RMSE: 0.1542
# Epoch 145/150
# 31/31 [==============================] - 3s 95ms/step - loss: 0.0936 - mae: 0.0766 - RMSE: 0.0941 - val_loss: 0.1992 - val_mae: 0.1923 - val_RMSE: 0.2130
# Epoch 146/150
# 31/31 [==============================] - 4s 122ms/step - loss: 0.0922 - mae: 0.0794 - RMSE: 0.0910 - val_loss: 0.2005 - val_mae: 0.1860 - val_RMSE: 0.2149
# Epoch 147/150
# 31/31 [==============================] - 3s 105ms/step - loss: 0.1038 - mae: 0.0879 - RMSE: 0.1045 - val_loss: 0.1939 - val_mae: 0.1650 - val_RMSE: 0.1988
# Epoch 148/150
# 31/31 [==============================] - 3s 90ms/step - loss: 0.1055 - mae: 0.0884 - RMSE: 0.1034 - val_loss: 0.1741 - val_mae: 0.1462 - val_RMSE: 0.1844
# Epoch 149/150
# 31/31 [==============================] - 3s 100ms/step - loss: 0.1171 - mae: 0.0985 - RMSE: 0.1168 - val_loss: 0.0988 - val_mae: 0.0742 - val_RMSE: 0.0968
# Epoch 150/150
# 31/31 [==============================] - 3s 97ms/step - loss: 0.0948 - mae: 0.0795 - RMSE: 0.0955 - val_loss: 0.1365 - val_mae: 0.1178 - val_RMSE: 0.1459

# %%
lstmDeaths.PlotLoss()
preds = lstmDeaths.PredictTest(lstmDeaths.X_test)
lstmDeaths.barplot(preds)
# Out:
# dict_keys(['loss', 'mae', 'RMSE', 'val_loss', 'val_mae', 'val_RMSE'])
# 1/1 [==============================] - 0s 1ms/step
# [[ 0.30861175]
#  [-0.35032564]
#  [-0.18133742]
#  [ 0.456285  ]
#  [ 0.7820133 ]
#  [ 1.1349223 ]
#  [ 0.3220983 ]
#  [ 0.33459795]
#  [-0.14325333]
#  [ 0.08247125]]
